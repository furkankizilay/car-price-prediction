# %%
# Replace {docker_username} with your Docker Hub username
docker_username = 'furkankizilay'
# Build and tage docker images
# !docker build -t {docker_username}/fastapi-car-price:1.0.3 .
# Push Docker images to Docker hub (Public repository)
# !docker push {docker_username}/fastapi-car-price:1.0.3
# Out:
# #1 [internal] load build definition from Dockerfile
# #1 sha256:5a68830f938cb57a359d15d52c6f03c43a668ad6566d1de39a5fd2556fa51045
# #1 transferring dockerfile: 407B 0.0s done
# #1 DONE 0.0s
#
# #2 [internal] load .dockerignore
# #2 sha256:152e9eb7bb0a074fc40e6572741b43c845f51f71d8862c34f909b1e765190687
# #2 transferring context: 2B done
# #2 DONE 0.0s
#
# #3 [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fastapi:python3.7
# #3 sha256:ad364a925e9753302d9ad20580104166a77b8049de436e5ca0154100aa96f55e
# #3 ...
#
# #4 [auth] tiangolo/uvicorn-gunicorn-fastapi:pull token for registry-1.docker.io
# #4 sha256:96de6cc57ac34dc734f0fc6e1ca1050ec69d1ef4e4340f7388a8eb7b6de6f230
# #4 DONE 0.0s
#
# #3 [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fastapi:python3.7
# #3 sha256:ad364a925e9753302d9ad20580104166a77b8049de436e5ca0154100aa96f55e
# #3 DONE 3.1s
# #1 [internal] load build definition from Dockerfile
# ...

# %%
# !docker run --name fastapi-server -d -p 80:80 -e WORKERS_PER_CORE="3" {docker_username}/fastapi-car-price:1.0.3
# Out:
# Unable to find image 'furkankizilay/fastapi-car-price:1.0.3' locally
# docker: Error response from daemon: manifest for furkankizilay/fastapi-car-price:1.0.3 not found: manifest unknown: manifest unknown.
# See 'docker run --help'.
